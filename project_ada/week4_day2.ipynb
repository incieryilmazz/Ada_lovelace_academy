# %% [markdown]
# #### API

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import requests

# %% [markdown]
# #### helpful docs:
# - what is API, REST
# - what is request, response and keys

# %%
url = "https://data.colorado.gov/resource/tv8u-hswn.json?$where=age between 20 and 25 and year between 2020 and 2025&county=Boulder&$select=year,age,femalepopulation"

# %%
url=url.replace(" ","%20")

# %%
data=pd.read_json(url)

# %%
data.head()
# Out:
#    year  age  femalepopulation
# 0  2022   22              3296
# 1  2020   20              3830
# 2  2020   21              3647
# 3  2021   24              2194
# 4  2023   23              2716

# %% [markdown]
# ### YOUTUBE API

# %%
from config import YOUTUBE_API_KEY

# %% [markdown]
# ##### youtube api key'e izin verdik enabled APIs & services'ten

# %%
#YOUTUBE_API_KEY= 'i ekledikten ve çalıştırdıktan sonra siliyoruz !
CHANNEL_ID="UC4-bGrwiQOCVpvQwEGWaqGA"
pageToken= ""
url = "https://www.googleapis.com/youtube/v3/search?key="+YOUTUBE_API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=1000"+pageToken

# %%
print(url)
# Out:
# https://www.googleapis.com/youtube/v3/search?key=AIzaSyBesPmogKQEQxU0ash72suIIEtP231wDcM&channelId=UC4-bGrwiQOCVpvQwEGWaqGA&part=snippet,id&order=date&maxResults=1000

# %%
response= requests.get(url).json()

# %%
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'qMiQc2WZtRs_eYfziAbNWwZycqE',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'TR',
#  'pageInfo': {'totalResults': 558, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '4iN_gdrBsifRPcLeBKQIIb4q0Kw',
#    'id': {'kind': 'youtube#video', 'videoId': 'NN9gjZR6hMk'},
#    'snippet': {'publishedAt': '2023-12-17T04:00:13Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Amerikan Dublaj Reklam',
#     'description': 'iletişim: noluyoya@temtalent.com.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/NN9gjZR6hMk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/NN9gjZR6hMk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/NN9gjZR6hMk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-17T04:00:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'zL0YvqMLfedJ1GYbnWRoAdAHePE',
#    'id': {'kind': 'youtube#video', 'videoId': 'QS965zBzjTY'},
#    'snippet': {'publishedAt': '2023-12-16T16:00:14Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Penguen Ben',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QS965zBzjTY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/QS965zBzjTY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/QS965zBzjTY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-16T16:00:14Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ZlBovNRQllHERnC88PbtrDvIyRU',
#    'id': {'kind': 'youtube#video', 'videoId': 'xM1FVlSfh5w'},
#    'snippet': {'publishedAt': '2023-12-15T16:00:05Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Kombo Şakalı Kıbrıs Vlog !',
#     'description': 'Kıbrıs maceramız kazalarla ve lezzetlerle dolu ayrıca harika birine konuk olduk umarım keyif alırsınız iyi seyirler :) Ayşeba kanalı ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xM1FVlSfh5w/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/xM1FVlSfh5w/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/xM1FVlSfh5w/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-15T16:00:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'mo9NmiUFs3PnLWlwa93dFR_T_no',
#    'id': {'kind': 'youtube#video', 'videoId': 'a4dZbbA9nvU'},
#    'snippet': {'publishedAt': '2023-12-13T16:00:00Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Yüzde Yüz Etkili',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/a4dZbbA9nvU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/a4dZbbA9nvU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/a4dZbbA9nvU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-13T16:00:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'kNA-Mvh66kkTjWVmR4hwMhXNdp4',
#    'id': {'kind': 'youtube#video', 'videoId': 'orXtvuq2sOo'},
#    'snippet': {'publishedAt': '2023-12-11T16:00:27Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Kayboldu mu köpek ?',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/orXtvuq2sOo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/orXtvuq2sOo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/orXtvuq2sOo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-11T16:00:27Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'V6zw8KpmTptenzzHmXp77CXT2bk',
#    'id': {'kind': 'youtube#video', 'videoId': '45pgh6vtC20'},
#    'snippet': {'publishedAt': '2023-12-10T18:07:01Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Burası sıcacık ☺️',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/45pgh6vtC20/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/45pgh6vtC20/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/45pgh6vtC20/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-10T18:07:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'dM-IayNRdtvawxqHmd9oFC9MLwQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'wiIT94I-PjM'},
#    'snippet': {'publishedAt': '2023-12-09T16:00:37Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Fırat Yüzünü Yıkarsa ..',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wiIT94I-PjM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/wiIT94I-PjM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/wiIT94I-PjM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-09T16:00:37Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'AexdYhkq4uu1IF59uiD0UNDjSdI',
#    'id': {'kind': 'youtube#video', 'videoId': 'x9qte2itheo'},
#    'snippet': {'publishedAt': '2023-12-08T16:00:27Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Çikolatalı Sokak Lezzetleri ! Vlog',
#     'description': 'Belçika çikolatası gerçekten güzel mi ? Peki nasıl yapılıyor ? Enteresan bir video ile geldik umarım keyif alırsınız iyi seyirler .',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/x9qte2itheo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/x9qte2itheo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/x9qte2itheo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-08T16:00:27Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'opMj_QCtvQ4dZVWy5xrOYosmIXY',
#    'id': {'kind': 'youtube#video', 'videoId': '16JvlzY6lWI'},
#    'snippet': {'publishedAt': '2023-12-06T16:00:01Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Kafanı dağıt !',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/16JvlzY6lWI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/16JvlzY6lWI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/16JvlzY6lWI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-06T16:00:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'iqdK-7f5KrvI-xe4kIIr_K5eHls',
#    'id': {'kind': 'youtube#video', 'videoId': 'mxETTp5j9sg'},
#    'snippet': {'publishedAt': '2023-12-04T16:00:26Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Heidi Efes’te',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mxETTp5j9sg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mxETTp5j9sg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mxETTp5j9sg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-04T16:00:26Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'XaIt811ElzA14eIG_1dij_KfA0E',
#    'id': {'kind': 'youtube#video', 'videoId': '6bN_o-QLqAc'},
#    'snippet': {'publishedAt': '2023-12-01T16:00:02Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Yeni Araba İle Cancık Sürücü',
#     'description': 'Yeni arabası ile utku ve Ceyda Kasabalı cancık sürücü kursuna dahil oluyor umarım eğlenirsiniz iyi seyirler :) Sponsorumuz: Her ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6bN_o-QLqAc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6bN_o-QLqAc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6bN_o-QLqAc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-01T16:00:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'x6a4lC6qzpWpNlWrZEpIDJu2RUM',
#    'id': {'kind': 'youtube#video', 'videoId': 'glrr9Sf5rTE'},
#    'snippet': {'publishedAt': '2023-11-24T16:00:02Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Yeni Köpeğimiz Değişik Joy !',
#     'description': 'Yeni köpeğimiz joy ile zorlu bir yolculuğa çıkıyoruz. Önce evcil hayvan ürünleri alışverişi için başlayan video dağlarda eğitimlerle ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/glrr9Sf5rTE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/glrr9Sf5rTE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/glrr9Sf5rTE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-11-24T16:00:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'VjGmIZTZlzNrGBSd_W3f92dFL5o',
#    'id': {'kind': 'youtube#video', 'videoId': 'XTxbIa-vuCU'},
#    'snippet': {'publishedAt': '2023-11-21T16:00:05Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Yanlışlıkla Tavuk Döner Yaptık !',
#     'description': "Mükemmel bir tavuk tarifi hemde mangalda çap çap ustadan geliyor :) Migros uygulaması içindeki Migros Yemek'ten hızlı ve sıcak ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XTxbIa-vuCU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XTxbIa-vuCU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XTxbIa-vuCU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-11-21T16:00:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Ww_0bLYCoSnjDDfFWSARBd3JvX8',
#    'id': {'kind': 'youtube#video', 'videoId': 'eb7yioXIQjo'},
#    'snippet': {'publishedAt': '2023-11-17T16:01:48Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Sıfırdan Hobi Odası Yenileme !',
#     'description': "Bu sefer Ceyda'nın hobi odasını yeniliyoruz. Gerçekten odayı baştan yarattık umarım keyif alırsınız iyi seyirler. Sponsorumuz: ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/eb7yioXIQjo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/eb7yioXIQjo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/eb7yioXIQjo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-11-17T16:01:48Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '0IQSWlyezEHLNso9hHdk-YvkjLg',
#    'id': {'kind': 'youtube#video', 'videoId': 'SHjuzI7-Bc0'},
#    'snippet': {'publishedAt': '2023-11-10T17:04:42Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Kahramanlar Gibi Belçika | Vlog',
#     'description': 'Alışveriş ve tatlının merkezi Belçika turumuz kahramanlıklarla dolu bir maceraya dönüştü. Çok eğlendik umarım sizlerde ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/SHjuzI7-Bc0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/SHjuzI7-Bc0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/SHjuzI7-Bc0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-11-10T17:04:42Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'UrE_ZsRbjn9Mr-jKWxb5H_J2nEs',
#    'id': {'kind': 'youtube#video', 'videoId': 'CxBa4L5IePo'},
#    'snippet': {'publishedAt': '2023-11-03T16:00:07Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Evimizde Yabancı Misafirleri Ağırladık  | Vlog',
#     'description': "Yurtdışından ta Hindistan'dan misafirlerimiz geldi. Elimizden geldiğince ağarlamaya çalıştık umarım keyif aldılar ve sizlerde ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/CxBa4L5IePo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/CxBa4L5IePo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/CxBa4L5IePo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-11-03T16:00:07Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '611SDtu28c9uA4QsB3p6yfoSgqY',
#    'id': {'kind': 'youtube#video', 'videoId': '-XUiTBQwTSA'},
#    'snippet': {'publishedAt': '2023-10-27T16:00:02Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Düşük Bütçeli Talk Şov | Kurgucu Utku',
#     'description': 'Evin ilk konuğu süper eğlenceli cancık Utku .Çok eğlenceli bir bölüm oldu umarım sizlerde eğlenirsiniz iyi seyirler:) Sponsorumuz: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-XUiTBQwTSA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-XUiTBQwTSA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-XUiTBQwTSA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-10-27T16:00:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'VJ5c03zuPI6pPn9ioU_Fy0jsSso',
#    'id': {'kind': 'youtube#video', 'videoId': 'LbE0svnD6KY'},
#    'snippet': {'publishedAt': '2023-10-13T16:00:16Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Noluyoya Tayfa İle Deniz Aşırı İyi Vlog',
#     'description': 'Ülke değiştiriyoruz hem de tekne ile ! Hem bu macerayı hem de Rodos turu çektiğimiz bu vlogda umarım eğlenirsiniz. iyi seyirler ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LbE0svnD6KY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/LbE0svnD6KY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/LbE0svnD6KY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-10-13T16:00:16Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ARO9hDaKRTwrecxdI0UcJ3URdCk',
#    'id': {'kind': 'youtube#video', 'videoId': 'VHo73RFrg8s'},
#    'snippet': {'publishedAt': '2023-10-06T16:00:34Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Noluyo Ya Dev Market Alışverişi | Vlog',
#     'description': 'Devasa market alışverişi yapmamız gerekiyor çünkü artık marketlere çok uzağız. O zaman 6 aylık alışveriş vlogu sizlerle :) İyi ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VHo73RFrg8s/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/VHo73RFrg8s/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/VHo73RFrg8s/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-10-06T16:00:34Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'x8SNcRip-TAkH1uajGS5eI3k9cA',
#    'id': {'kind': 'youtube#video', 'videoId': 'QRiFAkFfC20'},
#    'snippet': {'publishedAt': '2023-09-29T16:00:36Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Noluyo Ya Köy Evi Turu Mu ? Obuaaa',
#     'description': 'Evet sonunda köye taşındık yeni evimizde artık daha kalabalığız henuz yerleşemesekte hem ofis hem ev turumuzu çektik umarım ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QRiFAkFfC20/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/QRiFAkFfC20/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/QRiFAkFfC20/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-09-29T16:00:36Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'wY4Mfg_jvUd4Iqoy-1auiq-9WH0',
#    'id': {'kind': 'youtube#video', 'videoId': 'ItBvWM40pzg'},
#    'snippet': {'publishedAt': '2023-09-22T16:00:36Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Şurdan Şuraya ! Taşınma Vlog',
#     'description': "Noluyo ya ekipçe taşınıyor ! Resmen bir göç videosu oldu biz yetmedik Utku'yu da taşıdık elbette bu sürecimiz eğlence dolu ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ItBvWM40pzg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ItBvWM40pzg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ItBvWM40pzg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-09-22T16:00:36Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '93uI0eXIIm1ipr6-NhDZK-s_iGo',
#    'id': {'kind': 'youtube#video', 'videoId': 'ZNiNDssZ5z4'},
#    'snippet': {'publishedAt': '2023-09-21T16:12:17Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Neyi Tuttun Burak !',
#     'description': 'iletişim: noluyoya@temtalent.com.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ZNiNDssZ5z4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ZNiNDssZ5z4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ZNiNDssZ5z4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-09-21T16:12:17Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '4UH3MD5Mdwjh1NL9CHuIpXyPafk',
#    'id': {'kind': 'youtube#video', 'videoId': 'uTnYIOmr3k4'},
#    'snippet': {'publishedAt': '2023-09-17T16:40:45Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Usta Çatalını Unuttun !',
#     'description': 'iletişim: noluyoya@temtalent.com.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uTnYIOmr3k4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/uTnYIOmr3k4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/uTnYIOmr3k4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-09-17T16:40:45Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'VWNOz_XQQfHoDUFfyyU-d0aX1Wk',
#    'id': {'kind': 'youtube#video', 'videoId': 'RMfMR_Uz7i0'},
#    'snippet': {'publishedAt': '2023-09-15T16:00:02Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Düşük Bütçeli Talk Şov \u200b\u2060@Sefo362',
#     'description': 'Evin son konuğu dinlenme listelerinin bir numarası Sefo ! Çok eğlenceli bir bölüm oldu umarım sizlerde eğlenirsiniz iyi seyirler:) ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RMfMR_Uz7i0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/RMfMR_Uz7i0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/RMfMR_Uz7i0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-09-15T16:00:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'p9VMN0SmSD4_b0_513lRVU_Ktfg',
#    'id': {'kind': 'youtube#video', 'videoId': 'DiLJx0hOWkw'},
#    'snippet': {'publishedAt': '2023-09-12T15:19:58Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Yaşıyosun Bu Hayatı Menajer',
#     'description': 'iletişim: noluyoya@temtalent.com.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DiLJx0hOWkw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/DiLJx0hOWkw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/DiLJx0hOWkw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-09-12T15:19:58Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'd9BOskIuj7fDiqmjRxsK4E96qBA',
#    'id': {'kind': 'youtube#video', 'videoId': 'RV-Rr2Fh--c'},
#    'snippet': {'publishedAt': '2023-09-08T16:00:03Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Öğrenci Evinde Pijama Partisi !',
#     'description': 'Canların evine konuk oluyoruz bizi harika ağırladılar. Çok keyifli bir gün geçirdik umarım sizlerde eğlenirsiniz iyi seyirler ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RV-Rr2Fh--c/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/RV-Rr2Fh--c/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/RV-Rr2Fh--c/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-09-08T16:00:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'd0CBYLmWHvs5x7pvbslvfO3VpwI',
#    'id': {'kind': 'youtube#video', 'videoId': '26bGg5QoACA'},
#    'snippet': {'publishedAt': '2023-09-06T16:00:02Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Kulaklık Sorunsalı',
#     'description': 'iletişim: noluyoya@temtalent.com.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/26bGg5QoACA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/26bGg5QoACA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/26bGg5QoACA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-09-06T16:00:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'w_m4fxhoW0YoMIcc_CtnrfmM-58',
#    'id': {'kind': 'youtube#video', 'videoId': 'z-qWFjbQqFY'},
#    'snippet': {'publishedAt': '2023-09-03T16:00:41Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Bir yıl boyunca duruşumu düzelttim',
#     'description': 'iletişim: noluyoya@temtalent.com.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/z-qWFjbQqFY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/z-qWFjbQqFY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/z-qWFjbQqFY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-09-03T16:00:41Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'OhoLImD8n7UiNOAp8af8_iFn9R4',
#    'id': {'kind': 'youtube#video', 'videoId': 'JCHahsK5KU0'},
#    'snippet': {'publishedAt': '2023-09-01T16:00:04Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Almasam da Olurdu Dedirtecek Garip Ürünler !',
#     'description': 'Bulabildiğimiz en ilginç ürünleri eğlenceli bir şekilde inceledik. Bu sefer çok fazla ürünümüz var umarım keyif alırsınız iyi seyirler ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JCHahsK5KU0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/JCHahsK5KU0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/JCHahsK5KU0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-09-01T16:00:04Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'BisGP_wcNOHAIDeOLS0ELzo-1hI',
#    'id': {'kind': 'youtube#video', 'videoId': 'isiMU5o410w'},
#    'snippet': {'publishedAt': '2023-08-31T04:00:24Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Milyonda Bir İhtimal',
#     'description': 'iletişim: noluyoya@temtalent.com.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/isiMU5o410w/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/isiMU5o410w/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/isiMU5o410w/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-08-31T04:00:24Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'yDvpbDMgbUfrMbR9nEKs1wvQyBE',
#    'id': {'kind': 'youtube#video', 'videoId': 'F004auXkllg'},
#    'snippet': {'publishedAt': '2023-08-30T04:00:14Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'TESLAMAT #shorts',
#     'description': 'Darüşşafaka Deprem Öğrenci Destek Kampanyası http://bit.ly/3m5nxTZ iletişim: noluyoya@temtalent.com.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/F004auXkllg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/F004auXkllg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/F004auXkllg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-08-30T04:00:14Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'yCSRb1ntMRTuAHBXt8md_titWCM',
#    'id': {'kind': 'youtube#video', 'videoId': 'gId-JeTGLUg'},
#    'snippet': {'publishedAt': '2023-08-29T04:00:32Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'TLC #shorts',
#     'description': 'Darüşşafaka Deprem Öğrenci Destek Kampanyası http://bit.ly/3m5nxTZ iletişim: noluyoya@temtalent.com.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gId-JeTGLUg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/gId-JeTGLUg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/gId-JeTGLUg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-08-29T04:00:32Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'FMLYISfLT-GxlP6fny2B1DklP24',
#    'id': {'kind': 'youtube#video', 'videoId': 'w2WNDQTONbY'},
#    'snippet': {'publishedAt': '2023-08-28T11:01:42Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Kaç Dinar ? #shorts',
#     'description': 'Darüşşafaka Deprem Öğrenci Destek Kampanyası http://bit.ly/3m5nxTZ iletişim: noluyoya@temtalent.com.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/w2WNDQTONbY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/w2WNDQTONbY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/w2WNDQTONbY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-08-28T11:01:42Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'U4ApAFjlyBxPRG1-9fS6lsjQFW4',
#    'id': {'kind': 'youtube#video', 'videoId': 'PIFxwZQhguQ'},
#    'snippet': {'publishedAt': '2023-08-25T16:00:30Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Düşük Bütçeli Talk Şov @sergendeveci',
#     'description': 'Bu hafta evimize herkesin sevdiği sandırıcı Sergen Deveci konuk oluyor çok eğlenceli bir bölüm oldu umarım sizlerde eğlenirsiniz ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PIFxwZQhguQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PIFxwZQhguQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PIFxwZQhguQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-08-25T16:00:30Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'xwCZTOqPVnOWkf1J8mOebHW34Sw',
#    'id': {'kind': 'youtube#video', 'videoId': 'z6C09VfejO0'},
#    'snippet': {'publishedAt': '2023-08-20T18:30:41Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Karayollarına Hastayım',
#     'description': 'Darüşşafaka Deprem Öğrenci Destek Kampanyası http://bit.ly/3m5nxTZ iletişim: noluyoya@temtalent.com.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/z6C09VfejO0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/z6C09VfejO0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/z6C09VfejO0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-08-20T18:30:41Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'h2B2L6MIugfpL90gKbGVqSpAYVI',
#    'id': {'kind': 'youtube#video', 'videoId': 'gjX_YO-BnpI'},
#    'snippet': {'publishedAt': '2023-08-18T16:00:27Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Korku Evi İle Cancık Utku Turu !',
#     'description': 'Bu sefer kurgucumuz utkuyu korkutmak için yepyeni bir eve gidiyoruz. Biz çekerken hem korktuk hem çok eğlendik umarım ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gjX_YO-BnpI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/gjX_YO-BnpI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/gjX_YO-BnpI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-08-18T16:00:27Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Zzsl7iQyl50N2BvJnHZZzRPvons',
#    'id': {'kind': 'youtube#video', 'videoId': 'lt2igWIvbh0'},
#    'snippet': {'publishedAt': '2023-08-16T16:00:40Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Trafikte Dans #shorts',
#     'description': 'iletişim: noluyoya@temagency.com iletişim: noluyoya@temtalent.com.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lt2igWIvbh0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lt2igWIvbh0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lt2igWIvbh0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-08-16T16:00:40Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ASgfif83gL7kxFbsZ21hFW3fm0M',
#    'id': {'kind': 'youtube#video', 'videoId': 'a4DSyAcVvXA'},
#    'snippet': {'publishedAt': '2023-08-15T16:43:03Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Yılan Tarifi Evde Yapmalık',
#     'description': 'iletişim: noluyoya@temtalent.com.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/a4DSyAcVvXA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/a4DSyAcVvXA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/a4DSyAcVvXA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-08-15T16:43:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'tbTtjwU3n6VT5GkfxLS5uI4vvws',
#    'id': {'kind': 'youtube#video', 'videoId': '4GnW921exmI'},
#    'snippet': {'publishedAt': '2023-08-11T16:00:13Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Buz Gibi Avm’de Bir Gece Geçirmemek!',
#     'description': 'Deniz Kemal beyi avm ye götürüp mükemmel bir gece geçirdik. Karlardan , yer çekimsiz ortama her katta ayrı bir eğlence ile ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4GnW921exmI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4GnW921exmI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4GnW921exmI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-08-11T16:00:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'iaz2tpozHxhP7N63FsUFhoX6O84',
#    'id': {'kind': 'youtube#video', 'videoId': 'fT6SnTfiSVw'},
#    'snippet': {'publishedAt': '2023-08-10T11:49:30Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Sis Atma #shorts',
#     'description': 'Darüşşafaka Deprem Öğrenci Destek Kampanyası http://bit.ly/3m5nxTZ iletişim: noluyoya@temtalent.com.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fT6SnTfiSVw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fT6SnTfiSVw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fT6SnTfiSVw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-08-10T11:49:30Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'X99rv2c-fSCHYWYwN4WAI5IdskQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'xUOHdub4WDQ'},
#    'snippet': {'publishedAt': '2023-08-06T15:00:40Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Gözlüklerim Nasıl ?  #shorts',
#     'description': 'iletişim: noluyoya@temagency.com iletişim: noluyoya@temtalent.com.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xUOHdub4WDQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/xUOHdub4WDQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/xUOHdub4WDQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-08-06T15:00:40Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'WYQrF5C0TkilKQUgV-yJ_Dg0krg',
#    'id': {'kind': 'youtube#video', 'videoId': 'Br17PbzfAFM'},
#    'snippet': {'publishedAt': '2023-08-04T16:00:07Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Muhteşem Meslekler ! Köpek Dansçıları',
#     'description': 'İnanılmaz zeki ve tatlı köpekler ile bir gün geçirdik bu sefer kendi köpeklerimiz de bize eşlik etti ama bu köpekler eğitmenleri Ece ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Br17PbzfAFM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Br17PbzfAFM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Br17PbzfAFM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-08-04T16:00:07Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '6hZK_0q0TW6VdGF-1xIEqhMXdXM',
#    'id': {'kind': 'youtube#video', 'videoId': '-Vg0tUtF-CA'},
#    'snippet': {'publishedAt': '2023-08-03T16:11:37Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'V harfi #shorts',
#     'description': 'Darüşşafaka Deprem Öğrenci Destek Kampanyası http://bit.ly/3m5nxTZ iletişim: noluyoya@temtalent.com.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-Vg0tUtF-CA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-Vg0tUtF-CA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-Vg0tUtF-CA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-08-03T16:11:37Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'nrJXOyuZR8lpJcNeSCDqQ_locZQ',
#    'id': {'kind': 'youtube#video', 'videoId': '2RO7McTaH3w'},
#    'snippet': {'publishedAt': '2023-08-02T15:00:02Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Kahve Damlasi #shorts',
#     'description': 'iletişim: noluyoya@temagency.com iletişim: noluyoya@temtalent.com.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2RO7McTaH3w/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/2RO7McTaH3w/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/2RO7McTaH3w/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-08-02T15:00:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ZUsxzw76Y4rJRV3itQTYquW1Z_8',
#    'id': {'kind': 'youtube#video', 'videoId': '3HKKmhLuyII'},
#    'snippet': {'publishedAt': '2023-07-27T14:03:55Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Sahura Uyanmak',
#     'description': 'iletişim: noluyoya@temtalent.com.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3HKKmhLuyII/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/3HKKmhLuyII/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/3HKKmhLuyII/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-27T14:03:55Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'RFeE-f9XclOBHHXjHoL_zan_BUw',
#    'id': {'kind': 'youtube#video', 'videoId': 'SA93sd-uwy8'},
#    'snippet': {'publishedAt': '2023-07-26T14:28:44Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Çift Alışverişi #shorts',
#     'description': 'iletişim: noluyoya@temagency.com iletişim: noluyoya@temtalent.com.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/SA93sd-uwy8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/SA93sd-uwy8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/SA93sd-uwy8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-26T14:28:44Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'C37U8pe_5ODy8GpmDITLg4ZNdcA',
#    'id': {'kind': 'youtube#video', 'videoId': 'ZQ4ZT-BjUsI'},
#    'snippet': {'publishedAt': '2023-07-20T15:00:32Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Kaydırak Rezaleti  #shorts',
#     'description': 'iletişim: noluyoya@temagency.com iletişim: noluyoya@temtalent.com.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ZQ4ZT-BjUsI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ZQ4ZT-BjUsI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ZQ4ZT-BjUsI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-20T15:00:32Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'yjsCxi5aeb1EIuInH4dOZ4aEUfM',
#    'id': {'kind': 'youtube#video', 'videoId': 'gwg-JyF776A'},
#    'snippet': {'publishedAt': '2023-07-18T15:00:34Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Tabak mı Pasta mı ? #shorts',
#     'description': 'iletişim: noluyoya@temagency.com iletişim: noluyoya@temtalent.com.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gwg-JyF776A/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/gwg-JyF776A/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/gwg-JyF776A/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-18T15:00:34Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'AL5elufbAP0iFOhh-1bhmCRF0Gs',
#    'id': {'kind': 'youtube#video', 'videoId': 'cZgkQQK0gHE'},
#    'snippet': {'publishedAt': '2023-07-17T08:33:04Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Şapırdatma Ağzını #shorts',
#     'description': 'iletişim: noluyoya@temagency.com iletişim: noluyoya@temtalent.com.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/cZgkQQK0gHE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/cZgkQQK0gHE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/cZgkQQK0gHE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-17T08:33:04Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'XeQuR9cRX4_16SRwUZHBJUjuQqg',
#    'id': {'kind': 'youtube#video', 'videoId': 'FSONuKga1N4'},
#    'snippet': {'publishedAt': '2023-07-15T16:19:32Z',
#     'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#     'title': 'Eğer Bunu Atarsam ..',
#     'description': 'Tam hali kanalda yayında :) iletişim: noluyoya@temtalent.com.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FSONuKga1N4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/FSONuKga1N4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/FSONuKga1N4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Noluyo Ya ¿',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-15T16:19:32Z'}}]}

# %%
response["items"][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': '4iN_gdrBsifRPcLeBKQIIb4q0Kw',
#  'id': {'kind': 'youtube#video', 'videoId': 'NN9gjZR6hMk'},
#  'snippet': {'publishedAt': '2023-12-17T04:00:13Z',
#   'channelId': 'UC4-bGrwiQOCVpvQwEGWaqGA',
#   'title': 'Amerikan Dublaj Reklam',
#   'description': 'iletişim: noluyoya@temtalent.com.',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/NN9gjZR6hMk/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/NN9gjZR6hMk/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/NN9gjZR6hMk/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Noluyo Ya ¿',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2023-12-17T04:00:13Z'}}

# %%
response["items"][0]["id"]["videoId"]
# Out:
# 'NN9gjZR6hMk'

# %%
response["items"][0]["snippet"]["title"]
# Out:
# 'Amerikan Dublaj Reklam'

# %%
response["items"][0]["snippet"]["publishedAt"]
# Out:
# '2023-12-17T04:00:13Z'

# %%
video_id=response["items"][0]["id"]["videoId"]
video_title=response["items"][0]["snippet"]["title"]
upload_time=response["items"][0]["snippet"]["publishedAt"]
upload_time=str(upload_time).split("T")[0]
print(upload_time)
print(video_title)
print(video_id)
# Out:
# 2023-12-17
# Amerikan Dublaj Reklam
# NN9gjZR6hMk

# %%
# for loop in response
for video in response["items"]:
    if video["id"]["kind"]=="youtube#video":
        video_title=video["snippet"]["title"]
        print(video_title)
# Out:
# Amerikan Dublaj Reklam
# Penguen Ben
# Kombo Şakalı Kıbrıs Vlog !
# Yüzde Yüz Etkili
# Kayboldu mu köpek ?
# Burası sıcacık ☺️
# Fırat Yüzünü Yıkarsa ..
# Çikolatalı Sokak Lezzetleri ! Vlog
# Kafanı dağıt !
# Heidi Efes’te
# Yeni Araba İle Cancık Sürücü
# Yeni Köpeğimiz Değişik Joy !
# Yanlışlıkla Tavuk Döner Yaptık !
# Sıfırdan Hobi Odası Yenileme !
# Kahramanlar Gibi Belçika | Vlog
# Evimizde Yabancı Misafirleri Ağırladık  | Vlog
# Düşük Bütçeli Talk Şov | Kurgucu Utku
# Noluyoya Tayfa İle Deniz Aşırı İyi Vlog
# Noluyo Ya Dev Market Alışverişi | Vlog
# Noluyo Ya Köy Evi Turu Mu ? Obuaaa
# Şurdan Şuraya ! Taşınma Vlog
# Neyi Tuttun Burak !
# Usta Çatalını Unuttun !
# Düşük Bütçeli Talk Şov ​⁠@Sefo362
# Yaşıyosun Bu Hayatı Menajer
# Öğrenci Evinde Pijama Partisi !
# Kulaklık Sorunsalı
# Bir yıl boyunca duruşumu düzelttim
# Almasam da Olurdu Dedirtecek Garip Ürünler !
# Milyonda Bir İhtimal
# TESLAMAT #shorts
# TLC #shorts
# Kaç Dinar ? #shorts
# Düşük Bütçeli Talk Şov @sergendeveci
# Karayollarına Hastayım
# Korku Evi İle Cancık Utku Turu !
# Trafikte Dans #shorts
# Yılan Tarifi Evde Yapmalık
# Buz Gibi Avm’de Bir Gece Geçirmemek!
# Sis Atma #shorts
# Gözlüklerim Nasıl ?  #shorts
# Muhteşem Meslekler ! Köpek Dansçıları
# V harfi #shorts
# Kahve Damlasi #shorts
# Sahura Uyanmak
# Çift Alışverişi #shorts
# Kaydırak Rezaleti  #shorts
# Tabak mı Pasta mı ? #shorts
# Şapırdatma Ağzını #shorts
# Eğer Bunu Atarsam ..

# %% [markdown]
# #### Bir kanalın videolarından istediğimiz bir videoya ulaşmaya çalışacağız

# %%
video_url_endpoint = "https://www.googleapis.com/youtube/v3/videos?id="+video_id_test+"&part=statistics&key="+YOUTUBE_API_KEY
video_id_test=video_id

# %%
response_video= requests.get(video_url_endpoint).json()

# %%
response_video
# Out:
# {'error': {'code': 400,
#   'message': 'API key expired. Please renew the API key.',
#   'errors': [{'message': 'API key expired. Please renew the API key.',
#     'domain': 'global',
#     'reason': 'badRequest'}],
#   'status': 'INVALID_ARGUMENT',
#   'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo',
#     'reason': 'API_KEY_INVALID',
#     'domain': 'googleapis.com',
#     'metadata': {'service': 'youtube.googleapis.com'}}]}}
