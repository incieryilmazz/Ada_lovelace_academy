# %%
import requests
import pandas as pd 
import matplotlib.pyplot as plt
import time

# %%
#YOUTUBE_API_KEY_EXERCİSE = ""
CHANNEL_ID="UCv6jcPwFujuTIwFQ11jt1Yw"
url = "https://www.googleapis.com/youtube/v3/search?key="+YOUTUBE_API_KEY_EXERCİSE+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=1000"

# %%
print(url)
# Out:
# https://www.googleapis.com/youtube/v3/search?key=AIzaSyCNkMjVtQHI2MNsl5gvg8Lz6FCRcz5Pq7M&channelId=UCv6jcPwFujuTIwFQ11jt1Yw&part=snippet,id&order=date&maxResults=1000

# %%
response= requests.get(url).json()

# %%
print(response)
# Out:
# {'kind': 'youtube#searchListResponse', 'etag': 'X6a7PIohVCSHBwCKjt7K0f0-U4c', 'nextPageToken': 'CDIQAA', 'regionCode': 'TR', 'pageInfo': {'totalResults': 822, 'resultsPerPage': 50}, 'items': [{'kind': 'youtube#searchResult', 'etag': '7XBtYD4_H7GwFSnLTB3C2tDc0pw', 'id': {'kind': 'youtube#video', 'videoId': 'L_aGUgy6yl4'}, 'snippet': {'publishedAt': '2023-12-17T06:00:08Z', 'channelId': 'UCv6jcPwFujuTIwFQ11jt1Yw', 'title': 'Tüm zamanların en başarılı Hollywood filmi hangisi?', 'description': 'Tüm zamanların en başarılı Hollywood filmini belirlemek için çeşitli metrikler kullanılıyor. Sizin e-ticaret başarınız için hemen ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/L_aGUgy6yl4/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/L_aGUgy6yl4/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/L_aGUgy6yl4/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Barış Özcan', 'liveBroadcastContent': 
# ...

# %%
response["items"][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': '7XBtYD4_H7GwFSnLTB3C2tDc0pw',
#  'id': {'kind': 'youtube#video', 'videoId': 'L_aGUgy6yl4'},
#  'snippet': {'publishedAt': '2023-12-17T06:00:08Z',
#   'channelId': 'UCv6jcPwFujuTIwFQ11jt1Yw',
#   'title': 'Tüm zamanların en başarılı Hollywood filmi hangisi?',
#   'description': 'Tüm zamanların en başarılı Hollywood filmini belirlemek için çeşitli metrikler kullanılıyor. Sizin e-ticaret başarınız için hemen ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/L_aGUgy6yl4/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/L_aGUgy6yl4/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/L_aGUgy6yl4/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Barış Özcan',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2023-12-17T06:00:08Z'}}

# %%
response["items"][0]["id"]["videoId"]
# Out:
# 'L_aGUgy6yl4'

# %%
response["items"][0]["snippet"]["title"]
# Out:
# 'Tüm zamanların en başarılı Hollywood filmi hangisi?'

# %%
response["items"][0]["snippet"]["publishedAt"]
# Out:
# '2023-12-17T06:00:08Z'

# %%
video_id=response["items"][1]["id"]["videoId"]
video_title=response["items"][1]["snippet"]["title"]
upload_time=response["items"][1]["snippet"]["publishedAt"]
upload_time=str(upload_time).split("T")[1]
print(upload_time)
print(video_title)
print(video_id)
# Out:
# 14:00:00Z
# Antarktika’nın Ortasında Hayalet Parçacıklar
# a5FqNZt1o0c

# %%
# for loop in response
for video in response["items"]:
    if video["id"]["kind"]=="youtube#video":
        video_title=video["snippet"]["title"]
        print(video_title)
# Out:
# Tüm zamanların en başarılı Hollywood filmi hangisi?
# Antarktika’nın Ortasında Hayalet Parçacıklar
# Domino Etkisi
# Tesla CYBERTRUCK nihayet çıktı!!!
# Demek Dünyayı Kurtarmak İstiyorsun? O zaman ARK yap!
# Dinozorlar Nasıl Yok Oldu?
# Yeni stüdyom bir uzay gemisi: TARDIS
# OpenAI, ChatGPT&#39;nin patronu Sam Altman&#39;ı Neden Kovdu?
# Belgesel sesleri neden sahte olmak zorunda!
# İnsanların soyu tükenirse, bir yıl sonra Dünya nasıl görünürdü?
# 30 gün boyunca her gün 22:22&#39;de yattım! Kaliteli uyku için 10, 3, 2, 1, 0 kuralı
# Dzhanibekov Etkisi Neden 10 Yıl Sır Gibi Saklandı?
# Cesur Yeni Dünya
# NÖROESTETİK - Sanat beyni nasıl dönüştürür?
# Alman Tanklarındaki En Büyük Hata!
# Titanik’e dalarken kaybolan denizaltıya ne oldu?
# Sahra Çölünü Güneş Panelleriyle Kaplarsak Ne Olur?
# Sanal gerçekliğin geleceği, Apple Vision Pro ve Meta Quest Pro hakkındaki düşüncelerim
# Profesörlerin Bile Çözemediği Boyama Problemi - Dört Renk Teoremi
# ...

# %%
video_id="a5FqNZt1o0c"
video_url_endpoint = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+YOUTUBE_API_KEY_EXERCİSE

# %%
response_video= requests.get(video_url_endpoint).json()

# %%
response_video["items"][0]["statistics"]
# Out:
# {'viewCount': '360499',
#  'likeCount': '14310',
#  'favoriteCount': '0',
#  'commentCount': '435'}

# %%
for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        video_title = video['snippet']['title']
        video_id = video['id']['videoId']
        upload_time = video['snippet']['publishedAt']
        upload_date= str(upload_time).split("T")[0]

        # collecting video statistics
        video_stats_url = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+YOUTUBE_API_KEY_EXERCİSE
        video_stats_response = requests.get(video_stats_url).json()

        view_count = video_stats_response['items'][0]["statistics"]["viewCount"]
        like_count = video_stats_response['items'][0]["statistics"]["likeCount"]

        print(video_title)
        print(video_id)
        print(upload_date)
        print(view_count)
        print(like_count)
        print("\n")
# Out:
# Tüm zamanların en başarılı Hollywood filmi hangisi?
# L_aGUgy6yl4
# 2023-12-17
# 237415
# 14155
#
#
# Antarktika’nın Ortasında Hayalet Parçacıklar
# a5FqNZt1o0c
# 2023-12-13
# 360499
# 14310
#
#
# Domino Etkisi
# 4RayX7iwz1Q
# 2023-12-10
# 242285
# 13641
#
#
# Tesla CYBERTRUCK nihayet çıktı!!!
# fTFyk-ZCj4s
# 2023-12-03
# 955574
# 32785
#
#
# Demek Dünyayı Kurtarmak İstiyorsun? O zaman ARK yap!
# K3iFTE795o0
# 2023-11-28
# 276813
# 15468
#
#
# Dinozorlar Nasıl Yok Oldu?
# JTw3usk_K7E
# 2023-11-26
# 431050
# 24320
#
#
# Yeni stüdyom bir uzay gemisi: TARDIS
# 7DFs2WifolI
# 2023-11-23
# 214384
# 12020
#
#
# OpenAI, ChatGPT&#39;nin patronu Sam Altman&#39;ı Neden Kovdu?
# sFSE37Ud0WM
# 2023-11-19
# 477832
# 21139
#
#
# Belgesel sesleri neden sahte olmak zorunda!
# 0PlJCIcYozU
# 2023-11-12
# 469244
# 24666
#
#
# İnsanların soyu tükenirse, bir yıl sonra Dünya nasıl görünürdü?
# wvqU4HtLEO4
# 2023-11-01
# 947529
# 36118
#
#
# ...

# %%
def get_video_statistics(video_id, YOUTUBE_API_KEY_EXERCİSE):
    # collecting video statistics
    video_stats_url = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+YOUTUBE_API_KEY_EXERCİSE
    video_stats_response = requests.get(video_stats_url).json()

    view_count = video_stats_response['items'][0]["statistics"]["viewCount"]
    like_count = video_stats_response['items'][0]["statistics"]["likeCount"]

    return view_count, like_count

# %%
def get_videos_from_channel(df, channel_id, YOUTUBE_API_KEY_EXERCİSE):
    # make API call
    pageToken = ""
    url = "https://www.googleapis.com/youtube/v3/search?key="+YOUTUBE_API_KEY_EXERCİSE+"&channelId="+channel_id+"&part=snippet,id&order=date&maxResults=1000"+pageToken
    
    response = requests.get(url).json()
    time.sleep(3)  

    for video in response["items"]:
        if video['id']['kind'] == 'youtube#video':
            video_title = video['snippet']['title']
            video_id = video['id']['videoId']
            upload_date = video['snippet']['publishedAt']
            upload_date= str(upload_date).split("T")[0]

            view_count, like_count = get_video_statistics(video_id, YOUTUBE_API_KEY_EXERCİSE)

            #save in pandas df
            df = df.append({
            "video_id": video_id,
            "video_title": video_title,
            "upload_date": upload_date,
            "view_count": view_count,
            "like_count": like_count
        }, 
        ignore_index=True)

    return df
